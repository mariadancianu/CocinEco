# %%
from openfoodfacts import API, APIVersion, Country, Environment, Flavor
import json
import pandas as pd

# %%
# https://openfoodfacts.github.io/openfoodfacts-python/

# %%
user_agent = "CocinEco/1.0 (maria.a3isp@gmail.com)"

# User-Agent is mandatory
api = API(user_agent=user_agent, 
          username=None,
          password=None,
          country=Country.world, # can we set a specific country here?
          flavor=Flavor.off,
          version=APIVersion.v2,
          environment=Environment.org)

# %%
code = "3017620422003"
api.product.get(code, fields=["code", "product_name"])
# {'code': '3017620422003', 'product_name': 'Nutella'}

# %%
api.product.text_search("mineral water")
# {"count": 3006628, "page": 1, "page_count": 20, "page_size": 20, "products": [{...}], "skip": 0}

# %%
res = api.product.text_search("mineral water")
# {"count": 3006628, "page": 1, "page_count": 20, "page_size": 20, "products": [{...}], "skip": 0}

len(res)

# %%
print(type(res))
print(res.keys())

# %%
for k, v in res.items():
    print(f"{k}: {v}")

# %%
# this filter probably is not returning correct results 
res = api.product.text_search("Italy")
# {"count": 3006628, "page": 1, "page_count": 20, "page_size": 20, "products": [{...}], "skip": 0}
for k, v in res.items():
    print(f"{k}: {v}")
# Out:
# count: 8174
# page: 1
# page_count: 20
# page_size: 20
# products: [{'_id': '8076809513753', '_keywords': ['190g', 'barilla', 'basil', 'condiment', 'genovese', 'gluten', 'green', 'grocerie', 'italy', 'no', 'pasta', 'pdo', 'pesto', 'sauce', 'triman'], 'abbreviated_product_name': 'Pesto alla genovese 190g', 'abbreviated_product_name_fr': 'Sauce pesto avec basilic 190g', 'abbreviated_product_name_fr_imported': 'Sauce pesto avec basilic 190g', 'abbreviated_product_name_imported': 'Pesto alla genovese 190g', 'added_countries_tags': [], 'additives_n': 1, 'additives_original_tags': ['en:e270'], 'additives_tags': ['en:e270'], 'allergens': 'en:milk,en:nuts', 'allergens_from_ingredients': 'en:milk, en:milk, en:milk, en:nuts, milk, milk, milk protein, milk', 'allergens_from_user': '(en) Milk,Nuts, en:milk, en:milk, en:milk', 'allergens_hierarchy': ['en:milk', 'en:nuts'], 'allergens_imported': 'Lait, Fruits à coque', 'allergens_lc': 'en', 'allergens_tags': ['en:milk', 'en:nuts'], 'amino_acids_prev_tags': [], 'amino_acids_tags': [], 'brands': 'Barilla', 'brands_imported': 'Barilla', 'brands_old': 'Barilla', 'brands_tags': ['barilla'], 'carbon_footprint_percent_of_known_ingredients': 1, 'categories': 'Condiments,Sauces,Pasta sauces,Pestos,Green pestos,Groceries', 'categories_hierarchy': ['en:condiments', 'en:sauces', 'en:pasta-sauces', 'en:pestos', 'en:green-pestos', 'en:Groceries'], 'categories_imported': 'Epicerie, Sauces, Sauces Pesto, Pestos au basilic', 'categories_lc': 'en', 'categories_old': 'Condiments, Sauces, Pasta sauces, Pestos, Green pestos, Groceries', 'categories_properties': {'agribalyse_food_code:en': '11179', 'ciqual_food_code:en': '11179'}, 'categories_properties_tags': ['all-products', 'categories-known', 'agribalyse-food-code-11179', 'agribalyse-food-code-known', 'agribalyse-proxy-food-code-unknown', 'ciqual-food-code-11179', 'ciqual-food-code-known', 'agribalyse-known', 'agribalyse-11179'], 'categories_tags': ['en:condiments', 'en:sauces', 'en:pasta-sauces', 'en:pestos', 'en:green-pestos', 'en:groceries'], 'category_properties': {'ciqual_food_name:en': 'Sauce, pesto, prepacked', 'ciqual_food_name:fr': 'Sauce pesto, préemballée'}, 'checked': 'on', 'checkers': [], 'checkers_tags': ['sebleouf'], 'ciqual_food_name_tags': ['sauce-pesto-prepacked'], 'cities_tags': [], 'code': '8076809513753', 'codes_tags': ['code-13', '8076809513xxx', '807680951xxxx', '80768095xxxxx', '8076809xxxxxx', '807680xxxxxxx', '80768xxxxxxxx', '8076xxxxxxxxx', '807xxxxxxxxxx', '80xxxxxxxxxxx', '8xxxxxxxxxxxx'], 'compared_to_category': 'en:groceries', 'complete': 1, 'completed_t': 1719085814, 'completeness': 1, 'conservation_conditions': 'Après ouverture, cette sauce se conserve 5 jours au réfrigérateur.', 'conservation_conditions_fr': 'Conserver au réfrigérateur après ouverture et consommer dans les 5 jours.', 'conservation_conditions_fr_imported': 'Conserver au réfrigérateur après ouverture et consommer dans les 5 jours.', 'correctors': [], 'correctors_tags': ['nounours', 'manu1400', 'nash', 'date-limite-app', 'kiliweb', 'scanbot', 'oishii', 'dhx', 'yuka.VDVvcUNLY2dvY3NxdWNVMzBBL1IzTXAzMnNlbWQzbUxPclFOSWc9PQ', 'openfoodfacts-contributors', 'yuka.SGJ3Ukxmd0ZuK3Nsa3NWdStTdmsyc0pONUppRllIdm5NTzBJSVE9PQ', 'magasins-u', 'almudenitaa', 'olofolleola4', 'foodrepo', 'barilla', 'barilla-off', 'musarana', 'roboto-app', 'clockwerx', '1billion', 'org-barilla', 'acuario', 'j2m9544', 'jligtenberg', 'hungergames', 'gourmet', 'org-barilla-france-sa', 'rdtr', 'inf', 'maxiper', 'charlesnepote', 'odinh', 'davidepio', 'packbot', 'fgouget', 'fpdsurveys', 'daop5510', 'prepperapp', 'halal-app-chakib', 'batogustin', 'spotter', 'itsjustruby', 'schwappi', 'sandman095', 'ompopo', 'amadeous', 'kirillmukhin', 'koreller', 'soodays', 'macrofactor', 'sebleouf', 'kacperwasik2005pl'], 'countries': 'Australia,Belgium,France,Germany,Morocco,Norway,Serbia,Sweden,Switzerland,United Kingdom,Poland', 'countries_beforescanbot': 'Belgien,Frankreich,Deutschland,Marokko,Norwegen,Schweiz', 'countries_hierarchy': ['en:australia', 'en:belgium', 'en:fra ...
# skip: 0

# %%
# results from one page only? only 20 products?
# products key has 20 items 
# each product has 335 keys 
len(res["products"])
# Out:
# 20

# %%
with open("product_example_1.json", "w") as f:
    json.dump(res["products"][0], f, indent=4)
with open("product_example_2.json", "w") as f:
    json.dump(res["products"][1], f, indent=4)

# %%
# "nutrient_levels" key -> this turns into 4 categories: fat, saturated-fat, sugars, salt 
# here we take all the potential values of this key for all the products, to have standardized columns in the DB
nutrient_levels_all_cat = []

for i, product in enumerate(res["products"]):
    nutrient_levels = product.get("nutrient_levels")
    
    if nutrient_levels is not None:
        nutrient_levels_cat = list(nutrient_levels.keys())

    nutrient_levels_all_cat.extend(nutrient_levels_cat)

nutrient_levels_all_cat = list(set(nutrient_levels_all_cat))
nutrient_levels_all_cat = [f"nutrient_levels_{c}" for c in nutrient_levels_all_cat]
print(len(nutrient_levels_all_cat))
nutrient_levels_all_cat
# Out:
# 4
# ['nutrient_levels_sugars',
#  'nutrient_levels_fat',
#  'nutrient_levels_saturated-fat',
#  'nutrient_levels_salt']

# %%
# "nutriments" key -> this turns into several other categories
# here we take all the potential values of this key for all the products, to have standardized columns in the DB
# (this key can have different subkeys for different products)
nutriments_levels_all_cat = []

for i, product in enumerate(res["products"]):
    nutrient_levels = product.get("nutriments")
    
    if nutrient_levels is not None:
        nutrient_levels_cat = list(nutrient_levels.keys())

    nutrient_levels_all_cat.extend(nutrient_levels_cat)

nutriments_levels_all_cat = list(set(nutrient_levels_all_cat))
nutriments_levels_all_cat = [f"nutriments_{c}" for c in nutriments_levels_all_cat]

print(len(nutriments_levels_all_cat))
nutriments_levels_all_cat
# Out:
# 131
# ['nutriments_nutrient_levels_saturated-fat',
#  'nutriments_nutrient_levels_fat',
#  'nutriments_nutrition-score-fr_100g',
#  'nutriments_sugars_value',
#  'nutriments_fruits-vegetables-nuts-estimate-from-ingredients_serving',
#  'nutriments_iron_unit',
#  'nutriments_sodium_100g',
#  'nutriments_fiber_100g',
#  'nutriments_energy-kj_value',
#  'nutriments_iron_label',
#  'nutriments_iron',
#  'nutriments_energy-kcal_prepared_unit',
#  'nutriments_alpha-linolenic-acid_value',
#  'nutriments_salt_value',
#  'nutriments_magnesium',
#  'nutriments_fat_unit',
#  'nutriments_carbohydrates_100g',
#  'nutriments_calcium_100g',
#  'nutriments_magnesium_serving',
#  'nutriments_fruits-vegetables-nuts_prepared_unit',
#  'nutriments_saturated-fat',
#  'nutriments_saturated-fat_unit',
#  'nutriments_carbohydrates_value',
#  'nutriments_phosphore_100g',
#  'nutriments_carbon-footprint-from-known-ingredients_serving',
#  'nutriments_energy-kj_value_computed',
#  'nutriments_phosphorus_serving',
#  'nutriments_energy-kcal_100g',
#  'nutriments_carbohydrates_serving',
#  'nutriments_salt_serving',
#  'nutriments_sugars',
#  'nutriments_alpha-linolenic-acid',
#  'nutriments_energy-kcal_value',
#  'nutriments_cocoa_value',
#  'nutriments_energy_100g',
#  'nutriments_fer_serving',
#  'nutriments_cocoa_100g',
#  'nutriments_energy_prepared_unit',
#  'nutriments_alcohol_prepared_unit',
#  'nutriments_alpha-linolenic-acid_unit',
#  'nutriments_iron_100g',
#  'nutriments_zinc_value',
#  'nutriments_iron_serving',
#  'nutriments_fer_100g',
#  'nutriments_fat_serving',
#  'nutriments_energy',
#  'nutriments_magnesium_100g',
#  'nutriments_cocoa',
#  'nutriments_nova-group',
#  'nutriments_proteins',
#  'nutriments_proteins_unit',
#  'nutriments_sugars_prepared_unit',
#  'nutriments_phosphorus_100g',
#  'nutriments_phosphorus_unit',
#  'nutriments_proteins_serving',
#  'nutriments_carbon-footprint-from-known-ingredients_100g',
#  'nutriments_phosphore_serving',
#  'nutriments_nutrient_levels_sugars',
#  'nutriments_proteins_prepared_unit',
#  'nutriments_phosphorus',
#  'nutriments_sterco-di-mucca_prepared_unit',
#  'nutriments_energy-kcal_unit',
#  'nutriments_sodium_unit',
#  'nutriments_zinc_label',
#  'nutriments_nova-group_serving',
#  'nutriments_sugars_unit',
#  'nutriments_energy-kj_serving',
#  'nutriments_sugars_100g',
#  'nutriments_phosphorus_label',
#  'nutriments_magnesium_label',
#  'nutriments_energy-kcal',
#  'nutriments_fat_100g',
#  'nutriments_fiber_value',
#  'nutriments_carbohydrates_unit',
#  'nutriments_fiber_prepared_unit',
#  'nutriments_salt_unit',
#  'nutriments_sodium_prepared_unit',
#  'nutriments_calcium',
#  'nutriments_proteins_value',
#  'nutriments_iron_value',
#  'nutriments_nova-group_100g',
#  'nutriments_calcium_label',
#  'nutriments_cocoa_unit',
#  'nutriments_saturated-fat_prepared_unit',
#  'nutriments_sodium_value',
#  'nutriments_saturated-fat_100g',
#  'nutriments_salt',
#  'nutriments_cocoa_serving',
#  'nutriments_cocoa_label',
#  'nutriments_fruits-vegetables-legumes-estimate-from-ingredients_100g',
#  'nutriments_salt_100g',
#  'nutriments_carbohydrates_prepared_unit',
#  'nutriments_zinc_unit',
#  'nutriments_fat',
#  'nutriments_energy-kj_100g',
#  'nutriments_proteins_100g',
#  'nutriments_carbohydrates',
#  'nutriments_energy-kj_prepared_unit',
#  'nutriments_fruits-vegetables-nuts-estimate-from-ingredients_100g',
#  'nutriments_saturated-fat_value',
#  'nutriments_sodium_serving',
#  'nutriments_nutrition-score-fr',
#  'nutriments_fruits-vegetables-legumes-estimate-from-ingredients_serving',
#  'nutriments_energy-kj',
#  'nutriments_fat_prepared_unit',
#  'nutriments_fiber_unit',
#  'nutriments_sodium',
#  'nutriments_phosphorus_value',
#  'nutriments_saturated-fat_serving',
#  'nutriments_zinc_serving',
#  'nutriments_energy_value',
#  'nutriments_zinc',
#  'nutriments_carbon-footprint-from-known-ingredients_product',
#  'nutriments_fiber_serving',
#  'nutriments_energy_serving',
#  'nutriments_fiber',
#  'nutriments_magnesium_unit',
#  'nutriments_alpha-linolenic-acid_100g',
#  'nutriments_sugars_serving',
#  'nutriments_fat_value',
#  'nutriments_magnesium_value',
#  'nutriments_zinc_100g',
#  'nutriments_salt_prepared_unit',
#  'nutriments_calcium_unit',
#  'nutriments_energy-kcal_serving',
#  'nutriments_energy_unit',
#  'nutriments_calcium_value',
#  'nutriments_energy-kj_unit',
#  'nutriments_carbon-footprint_prepared_unit',
#  'nutriments_energy-kcal_value_computed',
#  'nutriments_nutrient_levels_salt']

# %%
keys_to_keep = [
    "product_name", 
    "categories_tags", 
    "ingredients_text",
    "manufacturing_places",
    "stores",
    "stores_tags"
]

print(len(nutrient_levels_all_cat))
print(len(nutriments_levels_all_cat))
print(len(keys_to_keep))

keys_to_keep.extend(nutrient_levels_all_cat)
#keys_to_keep.extend(nutriments_levels_all_cat)

print(len(keys_to_keep))
keys_to_keep
# Out:
# 4
# 131
# 6
# 10
# ['product_name',
#  'categories_tags',
#  'ingredients_text',
#  'manufacturing_places',
#  'stores',
#  'stores_tags',
#  'nutrient_levels_sugars',
#  'nutrient_levels_fat',
#  'nutrient_levels_saturated-fat',
#  'nutrient_levels_salt']

# %%
from collections import defaultdict

def get_simple_keys(product, keys):

    result = {k: None for k in keys}

    for k in keys:
        if k in product:
            result[k] = product[k]

    return result


def get_sub_dict_results(product, key, all_subkeys):
        
    result = {k: None for k in all_subkeys}

    if key in product:
        sub_dict = product[key]
   
        for k in all_subkeys:

            subkey_updated = k.replace(f"{key}_", "")

            if subkey_updated in sub_dict:
                result[k] = sub_dict[subkey_updated]
  
    return result

# %%
all_res = []

# TODO: generalize this code for all possible dict/list that we want to keep 

simple_keys = ['product_name',
 'categories_tags',
 'ingredients_text',
 'manufacturing_places',
 'stores',
 'stores_tags'
 ]

nutrient_levels_subkeys = nutrient_levels_all_cat.copy()
nutriments_levels_subkeys = nutriments_levels_all_cat.copy()

for i, product in enumerate(res["products"]):
    product_res_dict = {}
    simple_results = get_simple_keys(product, simple_keys)
    nutrients_results = get_sub_dict_results(product, key="nutrient_levels", all_subkeys=nutrient_levels_subkeys)
    nutriments_levels_results = get_sub_dict_results(product, key="nutriments", all_subkeys=nutriments_levels_subkeys)

    product_res_dict.update(simple_results)
    product_res_dict.update(nutrients_results)
    product_res_dict.update(nutriments_levels_results)

    all_res.append(product_res_dict)

df_full = pd.DataFrame(all_res)
df_full.head()
# Out:
#                                         product_name  \
# 0                        Pesto Genovese 190g Barilla
# 1                             Bio-Almond-Mandelmilch
# 2          BjORG AMANDE ALMOND SANS SUGRES- NO SUGAR
# 3  Organic Piadina 4 Wholeblend Flatbreads with E...
# 4                       Classic Torinesi Breadsticks
#
#                                      categories_tags  \
# 0  [en:condiments, en:sauces, en:pasta-sauces, en...
# 1  [en:beverages-and-beverages-preparations, en:p...
# 2  [en:plant-based-foods-and-beverages, en:bevera...
# 3  [en:plant-based-foods-and-beverages, en:plant-...
# 4  [en:plant-based-foods-and-beverages, en:plant-...
#
#                                     ingredients_text manufacturing_places  \
# 0  sunflower oil, fresh basil 30%, cashew nuts, p...                Italy
# 1  Bio-Getränk auf Mandelbasis, ohne Zucker. : Wa...               Italie
# 2  Lait d'amandes (eau, amandes 2,8%), amidon de ...               Italie
# 3  Wholemeal Wheat Flour (35%)*, Wheat Flour&quot...
# 4  Wheat Flour, Extra Virgin Olive Oil (7%), Malt...                 None
#
#                                               stores  \
# 0  carrefour.fr,Coop Obs!,Denner AG,Carrefour,Sup...
# 1                                               Lidl
# 2         Magasins U,Intermarché,Auchan,carrefour.fr
# 3                                         sainsburys
# 4                                     Waitrose,Tesco
#
#                                          stores_tags nutrient_levels_sugars  \
# 0  [carrefour-fr, coop-obs, denner-ag, carrefour,...               moderate
# 1                                             [lidl]                    low
# 2    [magasins-u, intermarche, auchan, carrefour-fr]                    low
# 3                                       [sainsburys]                    low
# 4                                  [waitrose, tesco]                    low
#
#   nutrient_levels_fat nutrient_levels_saturated-fat nutrient_levels_salt  ...  \
# 0                high                          high                 high  ...
# 1                 low                           low                  low  ...
# 2            moderate                           low                  low  ...
# 3            moderate                      moderate                 high  ...
# 4            moderate                           low                 high  ...
#
#   nutriments_zinc_100g nutriments_salt_prepared_unit  nutriments_calcium_unit  \
# 0                  NaN                             g                     None
# 1                  NaN                          None                     None
# 2                  NaN                          None                       mg
# 3                  NaN                          None                     None
# 4                  NaN                          None                     None
#
#    nutriments_energy-kcal_serving  nutriments_energy_unit  \
# 0                           234.0                      kJ
# 1                            27.0                      kJ
# 2                             NaN                      kJ
# 3                             NaN                      kJ
# 4                             NaN                      kJ
#
#   nutriments_calcium_value  nutriments_energy-kj_unit  \
# 0                      NaN                         kJ
# 1                      NaN                         kJ
# 2                     60.0                         kJ
# 3                      NaN                         kJ
# 4                      NaN                         kJ
#
#    nutriments_carbon-footprint_prepared_unit  \
# 0                                          g
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
#
#    nutriments_energy-kcal_value_computed nutriments_nutrient_levels_salt
# 0                                  491.8                            None
# 1                                   26.4                            None
# 2                                   25.5                            None
# 3                                  304.7                            None
# 4                                  440.1                            None
#
# [5 rows x 141 columns]

# %%
for idx, row in df_full.iterrows():
    print("------")
    print(row.product_name)
    print(row.categories_tags)
    print(row.ingredients_text)
    print(row.manufacturing_places)
    print(row.stores)
    print(row.stores_tags)
    print(row.nutrient_levels_fat)
    print("\n")
# Out:
# ------
# Pesto Genovese 190g Barilla
# ['en:condiments', 'en:sauces', 'en:pasta-sauces', 'en:pestos', 'en:green-pestos', 'en:groceries']
# sunflower oil, fresh basil 30%, cashew nuts, parmigiano reggiano pdo cheese 5%, (milk), maize fibre, whey powder (milk), salt, milk protein, extra virgin olive oil, sugar, basil extract, natural flavourings (milk), acidity regulator: lactic acid, garlic
# Italy
# carrefour.fr,Coop Obs!,Denner AG,Carrefour,Super U
# ['carrefour-fr', 'coop-obs', 'denner-ag', 'carrefour', 'super-u']
# high
#
#
# ------
# Bio-Almond-Mandelmilch
# ['en:beverages-and-beverages-preparations', 'en:plant-based-foods-and-beverages', 'en:beverages', 'en:plant-based-foods', 'en:dairy-substitutes', 'en:milk-substitutes', 'en:nuts-and-their-products', 'en:plant-based-beverages', 'en:plant-based-milk-alternatives', 'en:nut-based-drinks', 'en:almond-based-drinks', 'en:fruhstucke', 'en:getranke', 'en:nusse-und-nussprodukte', 'en:pflanzliche-getranke', 'en:pflanzliche-lebensmittel-und-getranke']
# Bio-Getränk auf Mandelbasis, ohne Zucker. : Wasser, 2,3% Mandeln geröstet!, Meersalz, Stabilisatoren: Johannisbrotkernmeh!', Gellan; Emulgator: Lecithine!. aus kontralliert õkologischer Landwirtschaft. Kann Spuren von Soja, glutenhaltigem Getreide und anderen Schalenfrüchten enthalten. Vor Wäme schützen und trocken lagem. Vor Gebrauch schüttein. Nach dem Öffnen im Kühlschrank lagem und innerhalb von 2-3 Tagen verzehren. Ungeöffnet mindestens haltbar bis: siehe Oberseite.
# Italie
# Lidl
# ['lidl']
# low
#
#
# ------
# BjORG AMANDE ALMOND SANS SUGRES- NO SUGAR
# ['en:plant-based-foods-and-beverages', 'en:beverages', 'en:plant-based-foods', 'en:dairy-substitutes', 'en:milk-substitutes', 'en:nuts-and-their-products', 'en:plant-based-beverages', 'en:plant-based-milk-alternatives', 'en:nut-based-drinks', 'en:almond-based-drinks', 'en:unsweetened-plain-almond-based-drinks']
# Lait d'amandes (eau, amandes 2,8%), amidon de riz, arôme naturel d'amande, sel marin, stabilisants: gomme guar, gomme xanthane
# Italie
# Magasins U,Intermarché,Auchan,carrefour.fr
# ['magasins-u', 'intermarche', 'auchan', 'carrefour-fr']
# moderate
#
#
# ------
# Organic Piadina 4 Wholeblend Flatbreads with Extra Virgin Olive Oil
# ['en:plant-based-foods-and-beverages', 'en:plant-based-foods', 'en:cereals-and-potatoes', 'en:breads', 'en:flatbreads', 'en:white-breads', 'en:piadina', 'en:wheat-breads', 'en:wheat-flatbreads']
# Wholemeal Wheat Flour (35%)*, Wheat Flour&quot;, Water, Extra Virgin Olive Oil (8%)*, Salt. Organic.
#
# sainsburys
# ['sainsburys']
# moderate
#
#
# ------
# Classic Torinesi Breadsticks
# ['en:plant-based-foods-and-beverages', 'en:plant-based-foods', 'en:cereals-and-potatoes', 'en:breads', 'en:breadsticks']
# Wheat Flour, Extra Virgin Olive Oil (7%), Malted Barley Flour, Salt, Yeast.
# None
# Waitrose,Tesco
# ['waitrose', 'tesco']
# moderate
#
#
# ------
# Piadina
# ['en:plant-based-foods-and-beverages', 'en:plant-based-foods', 'en:cereals-and-potatoes', 'en:breads', 'en:flatbreads']
# Durum Wheat Flour, Water, Extra Virgin Olive Oil, Salt.
# None
# Waitrose,tesco,Dunnes Stores
# ['waitrose', 'tesco', 'dunnes-stores']
# moderate
#
#
# ------
# Pesto alla Genovese
# ['en:condiments', 'en:sauces', 'en:pestos', 'en:green-pestos']
# Huiles végétales (olive, tournesol), basilic frais 30%, NOIX DE CAJOU, fromage Parmigiano Reggiano AOP 5% (LAIT), fibre de maïs, lactosérum en poudre (LAIT), sel, protéines de LAIT, huile d'olive vierge extra, sucre, extrait de basilic, arômes naturels (LAIT), correcteur d'acidité : acide lactique, ail. Peut contenir des traces d'autres FRUITS À COQUE.
# Parma
# Netto,nahkauf
# ['netto', 'nahkauf']
# high
#
#
# ------
# Chopped Tomatoes
# ['en:plant-based-foods-and-beverages', 'en:plant-based-foods', 'en:fruits-and-vegetables-based-foods', 'en:canned-foods', 'en:vegetables-based-foods', 'en:canned-plant-based-foods', 'en:vegetables', 'en:canned-vegetables', 'en:tomatoes-and-their-products', 'en:tomatoes', 'en:canned-tomatoes', 'en:peeled-tomatoes', 'de:gehackte-tomaten']
# 60% chopped tomatoes, 39,9% tomato juice, acidity regulator: citric acid
# AR Industrie Alimentari SpA - Loc Incoronata Zona ASI,71100 Foggia,(FG : Foggia),Pouilles,Italie,Italien
# Lidl
# ['lidl']
# low
#
#
# ------
# Italian Original Breadsticks
# ['en:plant-based-foods-and-beverages', 'en:plant-based-foods', 'en:cereals-and-potatoes', 'en:breads', 'en:breadsticks']
# _Wheat_ Flour, Olive Oil 7%, Yeast, _Barley_ Malt Extract, Salt.
#
# Tesco
# ['tesco']
# moderate
#
#
# ------
# Galettes boulghour & épeautre
# ['en:meat-alternatives', 'en:vegetarian-patties', 'en:cereals-and-vegetables-patties']
# Boulghour de blé complet* réhydraté 44,3 %, épeautre (blé*) cuit 13,5 %, huiles végétales* (tournesol oléique* et tournesol*), carottes* 6,2%, oignons* 5 %, flocons de blé complet* 4,6%, flocons d'avoine complète*, concentré de tomates* 4,1 %, poivrons rouges* 3,4 %, farine de riz*, céleri rave* 1,4 %, ail*, raisins secs*, sel de mer, gluten de blé*, épices*. *Ingrédients issus de l'agriculture biologique.
# Sud-Ouest de la France
# Carrefour Market,Magasins U,Leclerc,carrefour.fr,Carrefour,Auchan
# ['carrefour-market', 'magasins-u', 'leclerc', 'carrefour-fr', 'carrefour', 'auchan']
# moderate
#
#
# ------
# Pesto Basilic extra frais
# ['en:plant-based-foods-and-beverages', 'en:plant-based-foods', 'en:condiments', 'en:culinary-plants', 'en:aromatic-plants', 'en:herbs', 'en:sauces', 'en:pasta-sauces', 'en:pestos', 'en:basil', 'en:green-pestos', 'fr:pesto-vert']
# fresh basil (37%), sunflower oil (26%), water, italian cheeses (pecorino romani, grana padano (contains or) 2,9%), glucose syrup, potato flakes, salt, extra virgin olive oil (2%), cashew nut flour, pine seeds (0,5%), acidifying srome l lactic acid, antioxidant, ascorbic acid,
# Italie
# Leclerc,Carrefour,carrefour.fr,Carrefour Market
# ['leclerc', 'carrefour', 'carrefour-fr', 'carrefour-market']
# high
#
#
# ------
# single origin milk chocolate
# ['en:snacks', 'en:sweet-snacks', 'en:cocoa-and-its-products', 'en:chocolates', 'en:milk-chocolates']
# Cocoa Butter, Dried Whole Milk, Cane Sugar, Cocoa Mass, Milk Fat, Vanilla Extract
#
# Marks & Spencer
# ['marks-spencer']
# high
#
#
# ------
# Margherita Sourdough Pizza
# ['en:meals', 'en:pizzas-pies-and-quiches', 'en:pizzas', 'en:vegetarian-pizzas', 'en:margherita-pizza', 'en:sourdough']
# Wheat Flour, Mozzarella Cheese (19%) (Cow's Milk), Water, Tomato (8%), Tomato Puree (8%), Sunflower Oil, Parmigiano Reggiano D.O.P. Cheese (Cow's Milk, Non-Vegetarian Rennet), Salt, Olive Oil, Sicilian Oregano (0.05%), Yeast.
# None
# None
# None
# moderate
#
#
# ------
# Pâtes spaghetti au blé complet integral 500g
# ['en:plant-based-foods-and-beverages', 'en:plant-based-foods', 'en:pastas', 'en:dry-pastas', 'en:spaghetti', 'de:vollkorn-hartweizen', 'en:aliments-d-origine-vegetale', 'en:aliments-et-boissons-a-base-de-vegetaux', 'en:cereales-et-derives', 'en:cereales-et-pommes-de-terre', 'en:pates-alimentaires', 'en:pates-alimentaires-de-cereales', 'en:pates-de-ble-dur', 'en:pates-de-ble-dur-complet', 'en:pates-seches', 'en:spaghettis-de-ble-dur', 'en:spaghettis-de-ble-dur-complet']
# Semoule complète de BLÉ dur. Peut contenir des traces de SOJA et de MOUTARDE.
# Italie,Grèce
# Leader Price,Franprix,Magasins U,Kaufland,Edeka,COMBI,REWE,LIDL,Denner,carrefour.fr,Consum
# ['leader-price', 'franprix', 'magasins-u', 'kaufland', 'edeka', 'combi', 'rewe', 'lidl', 'denner', 'carrefour-fr', 'consum']
# low
#
#
# ------
# Italian Tomato Purée
# ['en:plant-based-foods-and-beverages', 'en:plant-based-foods', 'en:fruits-and-vegetables-based-foods', 'en:condiments', 'en:vegetables-based-foods', 'en:sauces', 'en:tomatoes-and-their-products', 'en:tomato-sauces', 'en:tomato-purees', 'en:groceries']
# Tomato Purée, Acidity Regulator (Citric Acid).
#
# Tesco
# ['tesco']
# low
#
#
# ------
# Chopped Tomatoes
# ['en:plant-based-foods-and-beverages', 'en:plant-based-foods', 'en:fruits-and-vegetables-based-foods', 'en:canned-foods', 'en:vegetables-based-foods', 'en:canned-plant-based-foods', 'en:vegetables', 'en:canned-vegetables', 'en:tomatoes-and-their-products', 'en:tomatoes', 'en:canned-tomatoes']
# Tomatoes 60%, Tomato Juice, Acidity Regulator (Citric Acid).
#
# Tesco
# ['tesco']
# low
#
#
# ------
# Durum wheat flatbreads
# ['en:plant-based-foods-and-beverages', 'en:plant-based-foods', 'en:cereals-and-potatoes', 'en:breads', 'en:flatbreads', 'en:white-breads', 'en:wheat-breads', 'en:wheat-flatbreads']
# Italian Reground Durum Wheat Semolina (67%), Water, Extra Virgin Olive Oil (8%), Salt. ALLERGEN ADVICE: For allergens, including cereals containing gluten, see ingredients in bold. May contain traces of mustard seed and soy.
# None
# None
# None
# moderate
#
#
# ------
# Soja nature sans sucre ajouté bio
# ['en:beverages-and-beverages-preparations', 'en:plant-based-foods-and-beverages', 'en:beverages', 'en:plant-based-foods', 'en:legumes-and-their-products', 'en:dairy-substitutes', 'en:milk-substitutes', 'en:plant-based-beverages', 'en:plant-based-milk-alternatives', 'en:legume-based-drinks', 'en:soy-based-drinks', 'en:unsweetened-plain-soy-based-drinks']
# eau, fèves de _soja_* 8%
# Italie
# intermarché,Magasins U,Monoprix,carrefour.fr
# ['intermarche', 'magasins-u', 'monoprix', 'carrefour-fr']
# moderate
#
#
# ------
# Kinder - Delice x10, 390g (13.8oz)
# ['en:snacks', 'en:desserts', 'en:sweet-snacks', 'en:biscuits-and-cakes', 'en:biscuits-and-crackers', 'en:cocoa-and-its-products', 'en:confectioneries', 'en:biscuits', 'en:chocolate-candies', 'en:cakes', 'en:chocolate-biscuits', 'en:chocolate-cakes']
# sugar, vegetable fats (palm, shea, sal), glucose-fructose syrup, humectant: glycerol, rehydrated milk powder 7%, wheat flour 6,5%, skimmed milk powder 5%, dextrose, lean cocoa 3%, cocoa 3%, egg 2,5%, lactoserum powder, concentrated pear juice, wheat starch, milk powder 0,5%, emulsifiers (lecithins [soy], mono and diglycerides of fatty acids), baking powders (ammonium carbonate, sodium acid carbonate), lemon juice concentrate, flavourings, cocoa butter, salt, cocoa paste, concentrated butter
#
# Magasins U,Delhaize,S-market
# ['magasins-u', 'delhaize', 's-market']
# high
#
#
# ------
# Chick Peas in Salted Water
# ['en:plant-based-foods-and-beverages', 'en:plant-based-foods', 'en:legumes-and-their-products', 'en:canned-foods', 'en:legumes', 'en:seeds', 'en:canned-plant-based-foods', 'en:legume-seeds', 'en:pulses', 'en:chickpeas', 'en:canned-legumes', 'en:canned-chickpeas']
# Chick Peas (60%), Water, Salt.
# Italy
# Sainsbury's
# ['sainsbury-s']
# low

# %%
df_full.to_csv("openfoodfacts_data.csv", index=False)
